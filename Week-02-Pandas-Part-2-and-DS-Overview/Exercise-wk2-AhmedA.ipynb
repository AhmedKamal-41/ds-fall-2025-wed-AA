# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)
df_food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.shape
# Out:
# (125, 61)

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.info()
'''df_info = pd.DataFrame({
    'Column': df_food.columns,
    'DataType': df_food.dtypes.values
})

df_info'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
df_clean = df_food[['calories_day','weight','Gender']]
df_clean
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
df_clean.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_clean = df_clean.dropna()

# %%
df_clean.isna().sum()
# Out:
# calories_day    0
# weight          0
# Gender          0
# dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 104 entries, 1 to 123
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   calories_day  104 non-null    float64
#  1   weight        104 non-null    object
#  2   Gender        104 non-null    int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
'''df_clean['weight'] = df_clean['weight'].astype(float)''' # basic convertion

df_clean['weight'] = pd.to_numeric(df_clean['weight'], errors='coerce')
# Out:
# /tmp/ipykernel_1942/957405510.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['weight'] = pd.to_numeric(df_clean['weight'], errors='coerce')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 104 entries, 1 to 123
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   calories_day  104 non-null    float64
#  1   weight        101 non-null    float64
#  2   Gender        104 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 3.2 KB

# %%
df_clean = df_clean.dropna()

# %%
df_clean.isna().sum()
# Out:
# calories_day    0
# weight          0
# Gender          0
# dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 1 to 123
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   calories_day  101 non-null    float64
#  1   weight        101 non-null    float64
#  2   Gender        101 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 3.2 KB

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
save_to_csv = df_clean.to_csv('/workspaces/ds-fall-2025-wed-AA/Week-02-Pandas-Part-2-and-DS-Overview/data/clean.csv',index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
salary_data_set_path = 'data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv'

df_salary = pd.read_csv(salary_data_set_path, sep='\t')
df_salary.head()
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
df_salary.shape
# Out:
# (28062, 18)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                             28062 non-null  object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
# 1) Strip leading/trailing whitespace from existing column names
df_salary.columns = df_salary.columns.str.strip()

# 2) Rename with corrected source keys
df_salary.rename(
    columns={
        'Timestamp': 'timestamp',
        'How old are you?': 'age',
        'What industry do you work in?': 'industry',
        'Job title': 'title',
        'If your job title needs additional context, please clarify here:': 'title_context',
        "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)": 'salary',
        'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.': 'additional_compensation',
        'Please indicate the currency:': 'currency',
        'If "Other," please indicate the currency here:': 'other_currency',
        'If your income needs additional context, please provide it here:': 'salary_context',
        'What country do you work in?': 'country',
        "If you're in the U.S., what state do you work in?": 'state',
        'What city do you work in?': 'city',
        'How many years of professional work experience do you have overall?': 'total_yoe',
        'How many years of professional work experience do you have in your field?': 'field_yoe',
        'What is your highest level of education completed?': 'highest_education_completed',
        'What is your gender?': 'gender',
        'What is your race? (Choose all that apply.)': 'race',
    },
    inplace=True
)
df_salary.columns
# Out:
# Index(['timestamp', 'age', 'industry', 'title', 'title_context', 'salary',
#        'additional_compensation', 'Please indicate the currency',
#        'other_currency', 'salary_context', 'country', 'state', 'city',
#        'total_yoe', 'field_yoe', 'highest_education_completed', 'gender',
#        'race'],
#       dtype='object')

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
industry_counts =  df_salary['industry'].value_counts()
industry_counts
# Out:
# industry
# Computing or Tech                        4699
# Education (Higher Education)             2464
# Nonprofits                               2419
# Health care                              1896
# Government and Public Administration     1889
#                                          ...
# Warehousing                                 1
# Education (Early Childhood Education)       1
# SAAS                                        1
# Health and Safety                           1
# Aerospace Manufacturing                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
top5 = industry_counts.head(5)
top5
# Out:
# industry
# Computing or Tech                       4699
# Education (Higher Education)            2464
# Nonprofits                              2419
# Health care                             1896
# Government and Public Administration    1889
# Name: count, dtype: int64

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
df_salary_tech = df_salary[(df_salary['industry'] == 'Computing or Tech')]
df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     28062 non-null  object
#  1   age                           28062 non-null  object
#  2   industry                      27988 non-null  object
#  3   title                         28061 non-null  object
#  4   title_context                 7262 non-null   object
#  5   salary                        28062 non-null  object
#  6   additional_compensation       20766 non-null  float64
#  7   Please indicate the currency  28062 non-null  object
#  8   other_currency                206 non-null    object
#  9   salary_context                3042 non-null   object
#  10  country                       28062 non-null  object
#  11  state                         23039 non-null  object
# ...

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 
print(df_salary_tech['industry'].unique())
# Out:
# ['Computing or Tech']

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
df_salary_usd = df_salary_tech[df_salary_tech['Please indicate the currency'] == 'USD']

titles = df_salary_usd['title'].unique()

for t in titles:
    print(t)
# Out:
# Systems Analyst
# Principal Software Engineer
# Intelligence Analyst
# Mobile developer
# Product Design Director
# Managed Services Sales Coordinator
# Technical specialist
# Tech Writer
# Senior Business Analyst
# senior web application developer
# Chief Engineer
# Senior Financial Analyst
# Product Manager
# Service Designer
# Software Development Manager
# technical support specialist
# Senior Technical Writer
# Business Analyst
# Supply chain manager
# Visual Designer
# IT Manager, Financial Systems
# Senior Manager of Customer Enablement
# Software Engineer
# Agile Coach
# principle product marketing manager
# Senior user experience researcher
# Salesforce Administrator
# Program Manager
# Junior Project Manager
# Software Development Project Manager
# Human Resources Manager
# Programmer Analyst 2
# Sr development Manager
# Technical Project Manager
# Marketing Specialist
# Sales
# Instructional designer
# Proposal Manager
# Business Architect
# Backend Elixir Engineer
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_usd['country'].value_counts().head()
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
# Name: count, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
us_names = ['United States','USA','U.S.','United States of America']
df_salary_usd['country'] = df_salary_usd['country'].replace(us_names,'US')
# Out:
# /tmp/ipykernel_21870/1037178180.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_usd['country'] = df_salary_usd['country'].replace(us_names,'US')

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_usd['country'].value_counts().head()
# Out:
# country
# US                3408
# United States       68
# Usa                 59
# USA                 56
# usa                 28
# Name: count, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
df_salary_usd['country'] = df_salary_usd['country'].replace(['United States ', 'Usa', 'USA ', 'usa'],'US')
df_salary_usd['country'].value_counts().head()
# Out:
# /tmp/ipykernel_21870/711113424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_usd['country'] = df_salary_usd['country'].replace(['United States ', 'Usa', 'USA ', 'usa'],'US')
# country
# US               3619
# United states      23
# united states      14
# Us                 12
# us                  9
# Name: count, dtype: int64

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.
df_salary_usd['country'] = df_salary_usd['country'].replace(['United states',' United states ', ' United states','united states','Us','us','U.S.A.',' United States of America','Unite States',' United State of America','Usa'],'US')
df_salary_usd['country'].value_counts().head()
# Out:
# /tmp/ipykernel_21870/2956340464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_usd['country'] = df_salary_usd['country'].replace(['United states',' United states ', ' United states','united states','Us','us','U.S.A.',' United States of America','Unite States',' United State of America','Usa'],'US')
# country
# US                          3699
# Israel                         5
# Canada                         4
# United States Of America       2
# U.S                            2
# Name: count, dtype: int64

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
df_salary_usd.groupby('state').agg({'salary':['min','max','mean']}).sort_values(('salary', 'mean'), ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
df_salary_usd['salary'] = pd.to_numeric(df_salary_usd['salary'], errors='coerce')
# Out:
# /tmp/ipykernel_21870/3842553586.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_usd['salary'] = pd.to_numeric(df_salary_usd['salary'], errors='coerce')

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
df_salary_usd.groupby('state').agg({'salary':['min','max','mean']}).sort_values(('salary', 'mean'), ascending=False)
# Out:
#                                salary
#                                   min        max      mean
# state
# Michigan, Texas, Washington  340000.0   340000.0  340000.0
# Florida                       28800.0  2600000.0  210711.0
# California, Oregon           200000.0   200000.0  200000.0
# California, Colorado         176000.0   176000.0  176000.0
# Delaware                     169000.0   169000.0  169000.0
# ...                               ...        ...       ...
# Mississippi                       NaN        NaN       NaN
# New York, Texas                   NaN        NaN       NaN
# North Dakota                      NaN        NaN       NaN
# South Dakota                      NaN        NaN       NaN
# Utah, Vermont                     NaN        NaN       NaN
#
# [66 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

df_salary_usd['timestamp'] = pd.to_datetime(df_salary_usd['timestamp'], errors='coerce')
# Out:
# /tmp/ipykernel_21870/3073299894.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_usd['timestamp'] = pd.to_datetime(df_salary_usd['timestamp'], errors='coerce')

# %%
new_df_ = df_salary_usd[df_salary_usd['timestamp'].dt.year.isin([2021, 2022, 2023])]
new_df_.tail()
# Out:
#                 timestamp    age           industry                title  \
# 27960 2023-05-09 17:57:30  45-54  Computing or Tech  Junior Data Analyst
# 27961 2023-05-28 16:10:53  45-54  Computing or Tech         Data Analyst
# 27971 2023-08-08 07:12:10  25-34  Computing or Tech       Data scientist
# 27975 2023-09-08 12:35:45  18-24  Computing or Tech               intern
# 27989 2023-10-26 08:17:05  18-24  Computing or Tech              Ibterb
#
#       title_context   salary  additional_compensation  \
# 27960           NaN  65000.0                      0.0
# 27961           NaN  65000.0                      0.0
# 27971           NaN    500.0                      NaN
# 27975           NaN  35000.0                      0.0
# 27989           NaN    456.0                      NaN
#
#       Please indicate the currency other_currency salary_context   country  \
# 27960                          USD            NaN            NaN        US
# ...

# %%
new_df_.groupby('state').agg({'salary':['min','max','mean']}).sort_values(('salary', 'mean'), ascending=False)
# Out:
#                                salary
#                                   min       max      mean
# state
# Michigan, Texas, Washington  340000.0  340000.0  340000.0
# California, Oregon           200000.0  200000.0  200000.0
# California, Colorado         176000.0  176000.0  176000.0
# Delaware                     169000.0  169000.0  169000.0
# Connecticut                   68000.0  270000.0  161610.0
# ...                               ...       ...       ...
# New York, Texas                   NaN       NaN       NaN
# North Dakota                      NaN       NaN       NaN
# South Carolina                    NaN       NaN       NaN
# South Dakota                      NaN       NaN       NaN
# Utah, Vermont                     NaN       NaN       NaN
#
# [66 rows x 3 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
df_salary['salary'] = pd.to_numeric(df_salary['salary'], errors='coerce')

df_salary.groupby('state').agg({'salary':['min','max','mean']}).sort_values(('salary', 'mean'), ascending=False)
# Out:
#                                 salary
#                                    min         max        mean
# state
# Alabama, South Carolina      5000000.0   5000000.0  5000000.00
# Alaska                         47840.0  10000000.0   702486.75
# Michigan, Texas, Washington   340000.0    340000.0   340000.00
# California, Oregon            200000.0    200000.0   200000.00
# California, Colorado          176000.0    176000.0   176000.00
# ...                                ...         ...         ...
# North Carolina, Utah               NaN         NaN         NaN
# Ohio, Washington                   NaN         NaN         NaN
# Ohio, Wyoming                      NaN         NaN         NaN
# Texas, Virginia                    NaN         NaN         NaN
# Utah, Vermont                      NaN         NaN         NaN
#
# [134 rows x 3 columns]

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
